# %% [markdown]
# # Phase 1

# %%
# for loading/processing the images  
from keras.preprocessing.image import load_img 
from keras.preprocessing.image import img_to_array 

# models 
from keras.models import Model

# clustering and dimension reduction
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# for everything else
import os
import numpy as np
import matplotlib.pyplot as plt
from random import randint
import pandas as pd
import pickle

from sklearn.metrics import silhouette_score

# %%
AliPC = True
KianaPC = False
path=""

if AliPC:
  path = r"E:\\University\\Term 8\\Computational Intelligence\\Project\\1\\Main-Project\\ML\\dataset\\input"
else:
  path = r"/content/drive/MyDrive/dataset"

os.chdir(path)

images = []

# creates a ScandirIterator aliased as files
with os.scandir(path) as files:
    for file in files:
            images.append(file.name)

# %%
if KianaPC:
    from google.colab import drive
    drive.mount('/content/drive')

# %%
from keras.applications.vgg16 import preprocess_input 
from keras.applications.vgg16 import VGG16 
from keras.applications.vgg19 import VGG19
from keras.applications.vgg19 import preprocess_input
from keras.models import Model
from keras.applications.resnet50 import ResNet50, preprocess_input

# %%
# load the model first and pass as an argument
# model = VGG16()
# model = VGG19()
# model = Model(inputs = model.inputs, outputs = model.layers[-2].output)
model = ResNet50(weights='imagenet', include_top=False, pooling='avg')

def extract_features(file, model):
    img = load_img(file, target_size=(224,224))
    img = np.array(img) 
    reshaped_img = img.reshape(1,224,224,3) 
    imgx = preprocess_input(reshaped_img)
    features = model.predict(imgx)
    return features.flatten()

# %%
import pickle
import numpy as np

# Define the path to the dataset pickle file
if AliPC:
    pkl_Path = r"E:\\University\\Term 8\\Computational Intelligence\\Project\\1\\Main-Project\\ML\\dataset\\dataset.pkl"
else:
    pkl_Path = r"/content/drive/MyDrive/dataset.pkl"

data = {}

# loop through each image in the dataset
for image in images:
    try:
        feat = extract_features(image, model) 
        data[image] = feat  
        print(image)  
    except Exception as ex: # if something fails, save the extracted features as a pickle file (optional)
        with open(pkl_Path, 'wb') as file:
            pickle.dump(data, file)
            print(f"Exception: {ex}")

with open(pkl_Path, 'wb') as file:
    pickle.dump(data, file)

filenames = np.array(list(data.keys()))

feat = np.array(list(data.values()))
# feat = feat.reshape(len(images), -1)
X = feat
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# subject01.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# subject01.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject01.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject01.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# subject01.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject01.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject01.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject01.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject01.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject01.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject01.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject02.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject02.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# subject02.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# subject02.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject02.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject02.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject02.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject02.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject02.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject02.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# subject02.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject03.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# subject03.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject03.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# subject03.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# subject03.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# subject03.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject03.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# subject03.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# subject03.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# subject03.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject03.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# subject04.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject04.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# subject04.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject04.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# subject04.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject04.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject04.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# subject04.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject04.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# subject04.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# subject04.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject05.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject05.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# subject05.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject05.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# subject05.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject05.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# subject05.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject05.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject05.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# subject05.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject05.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# subject06.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject06.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# subject06.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# subject06.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# subject06.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# subject06.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject06.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# subject06.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject06.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject06.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject06.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# subject07.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# subject07.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# subject07.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# subject07.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# subject07.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject07.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# subject07.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject07.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject07.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# subject07.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject07.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject08.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject08.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject08.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject08.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# subject08.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# subject08.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# subject08.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject08.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject08.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject08.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject08.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# subject09.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject09.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject09.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# subject09.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# subject09.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# subject09.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# subject09.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject09.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject09.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject09.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject09.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# subject10.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# subject10.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# subject10.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject10.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject10.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject10.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# subject10.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# subject10.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject10.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# subject10.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# subject10.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject11.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# subject11.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject11.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject11.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject11.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject11.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject11.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject11.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# subject11.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# subject11.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject11.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# subject12.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject12.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject12.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject12.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# subject12.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject12.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject12.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject12.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject12.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# subject12.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# subject12.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject13.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# subject13.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# subject13.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject13.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject13.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject13.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject13.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject13.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject13.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# subject13.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# subject13.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# subject14.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# subject14.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# subject14.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject14.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject14.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject14.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# subject14.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# subject14.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject14.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# subject14.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# subject14.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# subject15.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject15.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject15.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject15.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# subject15.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# subject15.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# subject15.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# subject15.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# subject15.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# subject15.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# subject15.wink

# %%
import os
import numpy as np
import pickle
from keras.preprocessing.image import load_img
from keras.applications.resnet50 import ResNet50, preprocess_input as preprocess_resnet
from keras.applications.vgg19 import VGG19, preprocess_input as preprocess_vgg19


model = VGG19()
model = Model(inputs = model.inputs, outputs = model.layers[-2].output)
# Load the pre-trained models
model_resnet = ResNet50(weights='imagenet', include_top=False, pooling='avg')
model_vgg19 = VGG19(weights='imagenet', include_top=False, pooling='avg')

# Function to extract features from an image file using ResNet50 model
def extract_features_resnet(file):
    img = load_img(file, target_size=(224,224))
    img = np.array(img) 
    reshaped_img = img.reshape(1,224,224,3) 
    imgx = preprocess_resnet(reshaped_img)
    features = model_resnet.predict(imgx)
    return features.flatten()

# Function to extract features from an image file using VGG19 model
def extract_features_vgg19(file):
    img = load_img(file, target_size=(224,224))
    img = np.array(img) 
    reshaped_img = img.reshape(1,224,224,3) 
    imgx = preprocess_vgg19(reshaped_img)
    features = model_vgg19.predict(imgx)
    return features.flatten()

# Directory containing the images
image_dir = path

# Initialize dictionaries to store filenames and their corresponding feature vectors
data_resnet = {}
data_vgg19 = {}

# Loop through each image in the dataset
for image_file in os.listdir(image_dir):
    try:
        # Get the full path of the image file
        image_path = os.path.join(image_dir, image_file)
        # Extract features from the image using ResNet50 and VGG19 models
        feat_resnet = extract_features_resnet(image_path)
        feat_vgg19 = extract_features_vgg19(image_path)
        # Store the filename and its corresponding feature vector in the dictionaries
        data_resnet[image_file] = feat_resnet
        data_vgg19[image_file] = feat_vgg19
        print(f"Extracted features for: {image_file}")
    except Exception as ex:
        # If an exception occurs, you can handle it here
        print(f"Exception occurred for {image_file}: {ex}")

# Save the dictionaries containing image filenames and their feature vectors as pickle files (optional)
pkl_path_resnet = "E:\\University\\Term 8\\Computational Intelligence\\Project\\1\\Main-Project\\ML\\dataset\\features_resnet.pkl"
pkl_path_vgg19 = "E:\\University\\Term 8\\Computational Intelligence\\Project\\1\\Main-Project\\ML\\dataset\\features_vgg19.pkl"
with open(pkl_path_resnet, 'wb') as file_resnet:
    pickle.dump(data_resnet, file_resnet)
with open(pkl_path_vgg19, 'wb') as file_vgg19:
    pickle.dump(data_vgg19, file_vgg19)

# Convert the dictionaries into numpy arrays of filenames and feature vectors
filenames_resnet = np.array(list(data_resnet.keys()))
features_resnet = np.array(list(data_resnet.values()))
filenames_vgg19 = np.array(list(data_vgg19.keys()))
features_vgg19 = np.array(list(data_vgg19.values()))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# Extracted features for: subject01.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Extracted features for: subject01.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step
# Extracted features for: subject01.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Extracted features for: subject01.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Extracted features for: subject01.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Extracted features for: subject01.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Extracted features for: subject01.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject01.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Extracted features for: subject01.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject01.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject01.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject02.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject02.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Extracted features for: subject02.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Extracted features for: subject02.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Extracted features for: subject02.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject02.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Extracted features for: subject02.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Extracted features for: subject02.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject02.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Extracted features for: subject02.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Extracted features for: subject02.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Extracted features for: subject03.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Extracted features for: subject03.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Extracted features for: subject03.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject03.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Extracted features for: subject03.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Extracted features for: subject03.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Extracted features for: subject03.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Extracted features for: subject03.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Extracted features for: subject03.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Extracted features for: subject03.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Extracted features for: subject03.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Extracted features for: subject04.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Extracted features for: subject04.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Extracted features for: subject04.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Extracted features for: subject04.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Extracted features for: subject04.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Extracted features for: subject04.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Extracted features for: subject04.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Extracted features for: subject04.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# Extracted features for: subject04.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Extracted features for: subject04.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Extracted features for: subject04.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Extracted features for: subject05.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject05.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Extracted features for: subject05.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Extracted features for: subject05.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Extracted features for: subject05.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject05.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Extracted features for: subject05.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Extracted features for: subject05.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Extracted features for: subject05.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Extracted features for: subject05.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject05.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject06.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Extracted features for: subject06.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Extracted features for: subject06.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Extracted features for: subject06.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Extracted features for: subject06.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Extracted features for: subject06.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Extracted features for: subject06.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject06.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Extracted features for: subject06.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# Extracted features for: subject06.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Extracted features for: subject06.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Extracted features for: subject07.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Extracted features for: subject07.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step
# Extracted features for: subject07.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Extracted features for: subject07.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject07.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject07.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject07.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Extracted features for: subject07.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Extracted features for: subject07.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject07.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject07.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject08.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject08.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject08.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject08.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject08.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject08.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Extracted features for: subject08.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Extracted features for: subject08.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject08.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Extracted features for: subject08.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step
# Extracted features for: subject08.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject09.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject09.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Extracted features for: subject09.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject09.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Extracted features for: subject09.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step
# Extracted features for: subject09.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject09.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject09.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject09.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject09.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject09.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject10.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Extracted features for: subject10.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject10.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Extracted features for: subject10.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Extracted features for: subject10.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject10.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# Extracted features for: subject10.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Extracted features for: subject10.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject10.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject10.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject10.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject11.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject11.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Extracted features for: subject11.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Extracted features for: subject11.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Extracted features for: subject11.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject11.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Extracted features for: subject11.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Extracted features for: subject11.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# Extracted features for: subject11.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Extracted features for: subject11.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Extracted features for: subject11.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject12.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject12.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject12.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Extracted features for: subject12.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# Extracted features for: subject12.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject12.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Extracted features for: subject12.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Extracted features for: subject12.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Extracted features for: subject12.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# Extracted features for: subject12.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Extracted features for: subject12.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject13.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Extracted features for: subject13.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step
# Extracted features for: subject13.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Extracted features for: subject13.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Extracted features for: subject13.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Extracted features for: subject13.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# Extracted features for: subject13.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Extracted features for: subject13.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Extracted features for: subject13.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Extracted features for: subject13.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# Extracted features for: subject13.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Extracted features for: subject14.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# Extracted features for: subject14.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# Extracted features for: subject14.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject14.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject14.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Extracted features for: subject14.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step
# Extracted features for: subject14.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Extracted features for: subject14.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject14.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step
# Extracted features for: subject14.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Extracted features for: subject14.wink
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject15.centerlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step
# Extracted features for: subject15.glasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Extracted features for: subject15.happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Extracted features for: subject15.leftlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Extracted features for: subject15.noglasses
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Extracted features for: subject15.normal
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Extracted features for: subject15.rightlight
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Extracted features for: subject15.sad
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Extracted features for: subject15.sleepy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Extracted features for: subject15.surprised
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Extracted features for: subject15.wink

# %%
# Print feature vectors extracted using ResNet50 model
print("Feature vectors extracted using ResNet50 model:")
for i, feature_vector in enumerate(features_resnet):
    print(f"Image {i+1}: {feature_vector}")

# Print feature vectors extracted using VGG19 model
print("\nFeature vectors extracted using VGG19 model:")
for i, feature_vector in enumerate(features_vgg19):
    print(f"Image {i+1}: {feature_vector}")
# Out:
# Feature vectors extracted using ResNet50 model:
# Image 1: [0.02305787 0.8265101  0.         ... 0.04192415 0.         0.7183198 ]
# Image 2: [0.00636835 0.991131   0.02059513 ... 0.         0.         0.5661028 ]
# Image 3: [0.03570947 0.7097495  0.1846161  ... 0.02119228 0.         0.9819132 ]
# Image 4: [0.05699953 0.33141997 0.         ... 0.14416899 0.         0.32199767]
# Image 5: [0.         0.1656083  0.01410281 ... 0.00942709 0.         0.50059897]
# Image 6: [0.         0.7816165  0.03898125 ... 0.         0.         0.448324  ]
# Image 7: [0.05959176 0.34281656 0.1413492  ... 0.07586595 0.         0.33149308]
# Image 8: [0.         0.5683519  0.05976339 ... 0.         0.         0.33956632]
# Image 9: [0.01901602 0.43033338 0.0283231  ... 0.         0.         0.51961374]
# Image 10: [0.         0.45615256 0.2263178  ... 0.         0.         0.6461715 ]
# Image 11: [0.07578021 0.48708445 0.07230999 ... 0.         0.         0.5465394 ]
# Image 12: [0.0023587  0.69837934 0.02729859 ... 0.07442454 0.03281354 0.25350586]
# Image 13: [0.01957007 0.2560089  0.03936129 ... 0.18400136 0.01490622 0.16112609]
# Image 14: [3.9257824e-01 7.3831433e-01 9.2253395e-06 ... 7.1325168e-02 1.3326650e-02
#  3.9858866e-01]
# Image 15: [0.04386673 0.3523993  0.         ... 0.29378602 0.03816057 0.24870281]
# Image 16: [0.3462858  0.693116   0.02882687 ... 0.14762528 0.         0.3044572 ]
# Image 17: [0.3462858  0.693116   0.02882687 ... 0.14762528 0.         0.3044572 ]
# Image 18: [0.14498079 0.6599279  0.         ... 0.         0.05891548 1.1696924 ]
# Image 19: [0.05586748 0.9452827  0.02173438 ... 0.16971149 0.00557616 0.3400822 ]
# Image 20: [0.2843943  0.6466014  0.06895389 ... 0.20819016 0.         0.27135047]
# Image 21: [0.1652361  0.08988673 0.05413137 ... 0.07264988 0.08311144 0.74962366]
# Image 22: [0.4677384  0.62833035 0.07307058 ... 0.07683739 0.         0.31788296]
# Image 23: [0.         0.20821106 0.         ... 0.         0.01907423 0.19721363]
# Image 24: [0.06018076 0.85983807 0.         ... 0.         0.03278653 0.5470733 ]
-01 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.04595590e+00 0.00000000e+00 2.00516844e+00 0.00000000e+00
#  1.11605197e-01 1.42376363e+00 0.00000000e+00 2.95441628e-01
#  0.00000000e+00 0.00000000e+00 1.43845350e-01 1.69494081e+00
#  6.63295165e-02 0.00000000e+00 0.00000000e+00 1.35319456e-01
#  9.18627754e-02 4.03368425e+00 0.00000000e+00 2.32093239e+00
#  7.56389201e-02 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.11127093e-01 3.47633779e-01 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 9.53822017e-01 2.65648305e-01 1.59262106e-01
#  2.76813960e+00 0.00000000e+00 1.86383677e+00 1.03399765e+00
#  2.24291444e-01 1.40433550e+00 2.24803352e+00 0.00000000e+00
#  0.00000000e+00 3.32983695e-02 0.00000000e+00 0.00000000e+00
#  3.00953716e-01 1.19079340e+00 1.25029191e-01 0.00000000e+00
#  0.00000000e+00 6.39215261e-02 3.85042310e-01 0.00000000e+00
#  1.98622003e-01 0.00000000e+00 0.00000000e+00 6.86830163e-01
#  3.65825921e-01 0.00000000e+00 1.53413210e-02 7.26968870e-02
#  2.69850403e-01 1.01700938e+00 4.31424268e-02 2.03745708e-01]

# %% [markdown]
# # Phase 2

# %%
from sklearn.manifold import TSNE
from skimage import io
from skimage.transform import resize

# %% [markdown]
# The parameter perplexity in the t-SNE algorithm is one of the key parameters that controls the amount of neighborhood of the input data that should be considered similar when constructing the low-dimensional embedding. More precisely, perplexity represents the number of nearest neighbors that each point in the original space should observe.
#
# Using different values of perplexity can lead to different results. Generally, smaller perplexity values tend to focus the algorithm on local relationship accuracy, while larger perplexity values tend to pay more attention to global structures. Choosing an appropriate value for perplexity depends on the experience and specific characteristics of your data.

# %%
import os
import seaborn as sns
from skimage import io
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import pandas as pd

# Define color map for subjects
# subject_color_map = {
#     'subject01': 'b',  # Blue
#     'subject02': 'g',  # Green
#     'subject03': 'r',  # Red
#     'subject04': 'c',  # Cyan
#     'subject05': 'm',  # Magenta
#     'subject06': 'y',  # Yellow
#     'subject07': 'k',  # Black
#     'subject08': 'tab:orange',  # Orange
#     'subject09': 'tab:brown',   # Brown
#     'subject10': 'tab:pink',    # Pink
#     'subject11': 'tab:gray',    # Gray
#     'subject12': 'tab:olive',   # Olive
#     'subject13': 'tab:cyan',    # Cyan
#     'subject14': 'tab:purple',  # Purple
#     'subject15': 'tab:blue'     # Light Blue
# }

# all of these have same color cause we dont know about number of subject and labels :)
subject_color_map = {
    'subject01': 'b',
    'subject02': 'b',
    'subject03': 'b',
    'subject04': 'b',
    'subject05': 'b',
    'subject06': 'b',
    'subject07': 'b',
    'subject08': 'b',
    'subject09': 'b',
    'subject10': 'b',
    'subject11': 'b',
    'subject12': 'b',
    'subject13': 'b',
    'subject14': 'b',
    'subject15': 'b',
}

# Load images
image_folder = path
image_files = os.listdir(image_folder)

# Preprocess images and extract features
images = []
subjects = []
for image_file in image_files:
    subject, _ = image_file.split('.', 1)  # Extract subject from filename
    subjects.append(subject)
    image_path = os.path.join(image_folder, image_file)
    image = io.imread(image_path)
    # Flatten image to create feature vector
    images.append(image.flatten())

# Convert list of images to numpy array
data = np.array(images)

# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)
pca_result = pca.fit_transform(feat)

# Apply t-SNE for dimensionality reduction
tsne = TSNE(n_components=2, perplexity=5, random_state=42) 
tsne_result = tsne.fit_transform(feat)

# Create a DataFrame for PCA result
df_pca = pd.DataFrame(pca_result, columns=['Principal Component 1', 'Principal Component 2'])
df_pca['Subject'] = subjects

# Create a DataFrame for t-SNE result
df_tsne = pd.DataFrame(tsne_result, columns=['t-SNE dim 1', 't-SNE dim 2'])
df_tsne['Subject'] = subjects

# Plot PCA result
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
sns.scatterplot(data=df_pca, x='Principal Component 1', y='Principal Component 2', hue='Subject', palette=subject_color_map, legend=False) #turn True legend for show subject table guide
plt.title('PCA Visualization')

# Plot t-SNE result
plt.subplot(1, 2, 2)
sns.scatterplot(data=df_tsne, x='t-SNE dim 1', y='t-SNE dim 2', hue='Subject', palette=subject_color_map, legend=False)
plt.title('t-SNE Visualization')

plt.show()

# %% [markdown]
# Due to above plot, we think t-SNE plotting is better than PCA. and the cluster number is around 17. cause we have 17 node of datas.
# We can use K-Means via K = 17 and due to result, change the K.

# %% [markdown]
# # Phase 3

# %% [markdown]
# ### K-Means

# %%
from yellowbrick.cluster import KElbowVisualizer
from sklearn.cluster import KMeans

# Initialize KMeans model
kmeans = KMeans(random_state=42)
kmeans.fit(feat)

# Instantiate the KElbowVisualizer with the KMeans model
visualizer = KElbowVisualizer(kmeans, k=(10,20))

# Fit the data and visualize the elbow method
visualizer.fit(feat)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
import shutil

clusterNum = 15

kmeans = KMeans(n_clusters=clusterNum, random_state=42)
kmeans.fit(feat)
predicted_labels = kmeans.labels_

# holds the cluster id and the images { id: [images] }
groups = {}
for file, cluster in zip(filenames,kmeans.labels_):
    if cluster not in groups.keys():
        groups[cluster] = []
        groups[cluster].append(file)
    else:
        groups[cluster].append(file)

# Create a folder to save the images
if AliPC:
    output_folder = f"E:\\University\\Term 8\\Computational Intelligence\\Project\\1\\Main-Project\\ML\\dataset\\output\\K-Means-with-K-{clusterNum}\\"
else:
    output_folder = "/content/drive/MyDrive/output/K-Means-with-K-{clusterNum}/"

os.makedirs(output_folder, exist_ok=True)

# holds the cluster id and the images { id: [images] }
groups = {}
for file, cluster in zip(filenames, kmeans.labels_):
    if cluster not in groups.keys():
        groups[cluster] = []
    groups[cluster].append(file)

# Save the images
for cluster_id, images in groups.items():
    cluster_folder = os.path.join(output_folder, f"cluster_{cluster_id}")
    os.makedirs(cluster_folder, exist_ok=True)
    for image_file in images:
        shutil.copy(image_file, cluster_folder)
print("Images saved successfully.")


# Perform PCA for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Perform t-SNE for visualization
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# Plot both PCA and t-SNE
plt.figure(figsize=(16, 6))

# Plot PCA
plt.subplot(1, 2, 1)
for cluster_label in set(predicted_labels):
    cluster_indices = predicted_labels == cluster_label
    plt.scatter(X_pca[cluster_indices, 0], X_pca[cluster_indices, 1], label=f'Cluster {cluster_label}', alpha=0.7)
plt.title('PCA K-Means Result')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

# Plot t-SNE
plt.subplot(1, 2, 2)
for cluster_label in set(predicted_labels):
    cluster_indices = predicted_labels == cluster_label
    plt.scatter(X_tsne[cluster_indices, 0], X_tsne[cluster_indices, 1], label=f'Cluster {cluster_label}', alpha=0.7)
plt.title('t-SNE K-Means Result')
plt.suptitle("K-Means Clustering")
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.legend()

plt.show()
# Out:
# Images saved successfully.

# %% [markdown]
# # DBSCAN

# %%
# Perform DBSCAN clustering
import shutil
from skimage import io
from skimage.transform import resize
from sklearn.metrics import accuracy_score
from collections import defaultdict
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
import numpy as np

# %%
# Define a range of parameter values to explore
eps_values = np.linspace(8, 15, 8)  # Adjust the range as needed
min_samples_values = range(1, 3)  # Adjust the range as needed

# Initialize lists to store silhouette scores
silhouette_scores = []

# Iterate over parameter combinations
for eps in eps_values:
    for min_samples in min_samples_values:
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        cluster_labels = dbscan.fit_predict(X)
        # Compute silhouette score
        silhouette_avg = silhouette_score(X, cluster_labels)
        silhouette_scores.append(silhouette_avg)

# Reshape silhouette scores into a 2D array
silhouette_scores = np.array(silhouette_scores).reshape(len(eps_values), len(min_samples_values))

# Plot silhouette scores
plt.figure(figsize=(10, 6))
for i, min_samples in enumerate(min_samples_values):
    plt.plot(eps_values, silhouette_scores[:, i], label=f"min_samples={min_samples}")
plt.title("Silhouette Scores for Different Parameter Combinations")
plt.xlabel("Epsilon (eps)")
plt.ylabel("Silhouette Score")
plt.legend()
plt.grid(True)
plt.show()

# %%
from sklearn.metrics import silhouette_score
# Determine the optimal number of clusters using silhouette score
silhouette_scores = []
min_samples = 2
StartRange=8
FinishRange=20
for eps in range(StartRange, FinishRange):  # Try different values of eps
    dbscan = DBSCAN(eps=eps, min_samples=min_samples)
    cluster_labels = dbscan.fit_predict(X)
    if dbscan.labels_.size > 0:
        silhouette_avg = silhouette_score(X, dbscan.labels_)
        silhouette_scores.append(silhouette_avg)

# Plot silhouette scores for different values of eps
import matplotlib.pyplot as plt

plt.plot(range(StartRange, FinishRange), silhouette_scores, marker='o')
plt.title("Silhouette Score vs. Eps (DBSCAN)")
plt.xlabel("Eps")
plt.ylabel("Silhouette Score")
plt.xticks(range(StartRange, FinishRange))
plt.grid(True)
plt.show()

# %%
eps = 11 # Adjust as needed
min_samples = 2 # Adjust as needed
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
predicted_labels = dbscan.fit_predict(X)
# print(cluster_labels)

# Preprocess filenames to extract labels
labels = [int(filename.split('.')[0].split('subject')[1]) for filename in image_files]

# Create a folder to save the images
if AliPC:
    cluster_output_dir = f"E:\\University\\Term 8\\Computational Intelligence\\Project\\1\\Main-Project\\ML\\dataset\\output\\DB-SCAN-with-eps-{eps}-min-{min_samples}\\"
else:
    cluster_output_dir = "/content/drive/MyDrive/output/DB-SCAN-with-eps-{eps}-min-{min_samples}/"

os.makedirs(cluster_output_dir, exist_ok=True)

# Move images to cluster-specific folders
for i, cluster_label in enumerate(predicted_labels):
    cluster_dir = os.path.join(cluster_output_dir, f"cluster_{cluster_label}")
    os.makedirs(cluster_dir, exist_ok=True)
    filename = os.listdir(path)[i]
    shutil.copy(os.path.join(path, filename), cluster_dir)

# Mapping cluster labels to actual labels based on majority vote
label_mapping = defaultdict(lambda: defaultdict(int))
for cluster_label, true_label in zip(predicted_labels, labels):
    label_mapping[cluster_label][true_label] += 1

# Perform PCA for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Perform t-SNE for visualization
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# Plot both PCA and t-SNE
plt.figure(figsize=(16, 6))

# Plot PCA
plt.subplot(1, 2, 1)
for cluster_label in set(predicted_labels):
    cluster_indices = predicted_labels == cluster_label
    plt.scatter(X_pca[cluster_indices, 0], X_pca[cluster_indices, 1], label=f'Cluster {cluster_label}', alpha=0.7)
plt.title('PCA DB-Scan Result')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

# Plot t-SNE
plt.subplot(1, 2, 2)
for cluster_label in set(predicted_labels):
    cluster_indices = predicted_labels == cluster_label
    plt.scatter(X_tsne[cluster_indices, 0], X_tsne[cluster_indices, 1], label=f'Cluster {cluster_label}', alpha=0.7)
plt.title('t-SNE DB-Scan Result')
plt.suptitle("DB-Scan Clustering")
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.legend()

plt.show()

# %% [markdown]
# # Agglomarative

# %%
from sklearn.cluster import AgglomerativeClustering


# Reshape X to 2D array
num_samples = X.shape[0]
num_features = np.prod(X.shape[1:])
X = X.reshape(num_samples, num_features)

n_clusters = 15  # Adjust as needed
agglomerative = AgglomerativeClustering(n_clusters=n_clusters)
predicted_labels = agglomerative.fit_predict(X)

clusteringMethod = "Agglomerative"

# Compute silhouette score
silhouette_avg = silhouette_score(X, predicted_labels)
print("Silhouette Score:", silhouette_avg)

# Perform PCA for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# Perform t-SNE for visualization
tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

# Plot both PCA and t-SNE
plt.figure(figsize=(16, 6))

# Plot PCA
plt.subplot(1, 2, 1)
for cluster_label in set(predicted_labels):
    cluster_indices = predicted_labels == cluster_label
    plt.scatter(X_pca[cluster_indices, 0], X_pca[cluster_indices, 1], label=f'Cluster {cluster_label}', alpha=0.7)
plt.title('PCA Agglomerative Result')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()

# Plot t-SNE
plt.subplot(1, 2, 2)
for cluster_label in set(predicted_labels):
    cluster_indices = predicted_labels == cluster_label
    plt.scatter(X_tsne[cluster_indices, 0], X_tsne[cluster_indices, 1], label=f'Cluster {cluster_label}', alpha=0.7)
plt.title('t-SNE Agglomerative Result')
plt.suptitle("Agglomerative Clustering")
plt.xlabel('t-SNE Dimension 1')
plt.ylabel('t-SNE Dimension 2')
plt.legend()

plt.show()
# Out:
# Silhouette Score: 0.19698605

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# Reshape X to 2D array
num_samples = X.shape[0]
num_features = np.prod(X.shape[1:])
X = X.reshape(num_samples, num_features)

# Calculate linkage matrix using Ward's method
Z = linkage(X, method='ward')

# Plot dendrogram
plt.figure(figsize=(15, 8))
dendrogram(Z)
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# # Phase 4 (Rand Index)

# %%
# Perform K-Means clustering
kmeans = KMeans(n_clusters=15, random_state=42)
kmeans.fit(feat)
predicted_labels = kmeans.labels_

clusteringMethod = "K-Means"

# %%
# Perform DB-Scan clustering
eps = 11
min_samples = 1
dbscan = DBSCAN(eps=eps, min_samples=min_samples)
cluster_labels = dbscan.fit_predict(X)
predicted_labels = cluster_labels

clusteringMethod = "DB-Scan"

# %%
# Perform Agglomerative clustering
n_clusters = 15 
agglomerative = AgglomerativeClustering(n_clusters=n_clusters)
predicted_labels = agglomerative.fit_predict(X)

clusteringMethod = "Agglomerative"

# %% [markdown]
# ### Our Rand-Index Implementation

# %%
def rand_index_method(labels_true, labels_pred):
    tp = fp = tn = fn = 0
    n = len(labels_true)
    for i in range(n):
        for j in range(i+1, n):
            if labels_true[i] == labels_true[j] and labels_pred[i] == labels_pred[j]:
                tp += 1
            elif labels_true[i] != labels_true[j] and labels_pred[i] != labels_pred[j]:
                tn += 1
            elif labels_true[i] == labels_true[j] and labels_pred[i] != labels_pred[j]:
                fn += 1
            else:
                fp += 1
    result = (tp + tn)/(tp + tn + fp + fn)
    return result

# print(labels, predicted_labels)

image_files = os.listdir(path)

# Preprocess filenames to extract labels
labels = [int(filename.split('.')[0].split('subject')[1]) for filename in image_files]

# Get the true labels and predicted labels
true_labels = labels

rand_index = rand_index_method(true_labels, predicted_labels)

print("Our Rand-Index:",rand_index)

# Apply PCA for dimensionality reduction
pca = PCA(n_components=50)  # You can adjust the number of components
pca_result = pca.fit_transform(feat)

# Apply t-SNE on the PCA result
tsne = TSNE(n_components=2, random_state=42)
tsne_result = tsne.fit_transform(feat)

# Plot the clusters
plt.figure(figsize=(16, 6))

# Plot PCA
plt.subplot(1, 2, 1)
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=predicted_labels, cmap='viridis')
plt.title(f'{clusteringMethod} PCA')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.colorbar(label='Cluster')

# Plot t-SNE
plt.subplot(1, 2, 2)
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=predicted_labels, cmap='viridis')
plt.title(f'{clusteringMethod} t-SNE')
plt.suptitle(f"Rand-Index: {rand_index}")
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.colorbar(label='Cluster')

plt.tight_layout()
plt.show()
# Out:
# Our Rand-Index: 0.9256467110125647

# %%
from sklearn.metrics import rand_score

# Load images
image_files = os.listdir(path)

# Preprocess filenames to extract labels
true_labels = [int(filename.split('.')[0].split('subject')[1]) for filename in image_files]

# print("labels:\n",labels)

# print("\npredicted_labels:\n",predicted_labels)

# Calculate the Rand-Index
rand_index = rand_score(true_labels, predicted_labels)
print(f"Implemented Rand-Index for {clusteringMethod}:{rand_index}")
# Out:
# Implemented Rand-Index for DB-Scan:0.9584626755358463
